# %%
import os
data_dir = '/home/schizoid-man/Documents/AWS_RAW_DATA'
txt_files = [f for f in os.listdir(data_dir) if f.endswith('.txt')]
texts = []
for file in txt_files:
    with open(os.path.join(data_dir, file), 'r', encoding='utf-8') as f:
        texts.append(f.read())

# %%
import re

def preprocess_text(text):
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = re.sub(r'[^\x00-\x7F]+', ' ', text)
    text = text.lower()
    return text

preprocessed_texts = [preprocess_text(text) for text in texts]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
combined_text = ' '.join(preprocessed_texts)

# Apply TF-IDF
vectorizer = TfidfVectorizer(stop_words='english', max_features=20)
X = vectorizer.fit_transform([combined_text])

# Get the keywords
keywords = vectorizer.get_feature_names_out()

# %%
from tqdm import tqdm
import nltk
from nltk import word_tokenize, pos_tag, ne_chunk

keywords_list = []
for text in preprocessed_texts:
    vectorizer = TfidfVectorizer(stop_words='english', max_features=20)
    tfidf_matrix = vectorizer.fit_transform([text])
    keywords = vectorizer.get_feature_names_out()
    keywords_list.append(keywords)

# Extract named entities using NLTK with a progress bar
named_entities_list = []
for text in tqdm(texts, desc="Extracting named entities"):
    tokens = word_tokenize(text)
    pos_tags = pos_tag(tokens)
    named_entities = ne_chunk(pos_tags)
    named_entities_list.append(named_entities)
# Out:
# Extracting named entities: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 347/347 [02:58<00:00,  1.95it/s]

# %%
for i, file in enumerate(txt_files):
    print(f"File: {file}")
    print(f"Keywords: {keywords_list[i]}")
    #print(f"Named Entities: {named_entities_list[i]}")
    print("\n")
# Out:
# File: Oportun Increases the Accuracy of Sensitive-Data Discovery by 95 Using Amazon Macie _ Oportun Case Study _ AWS.txt
# Keywords: ['accuracy' 'amazon' 'aws' 'buckets' 'carlos' 'data' 'discovery'
#  'identify' 'macie' 'oportun' 'pii' 'risk' 'says' 'scan' 'security'
#  'service' 'services' 'solution' 'team' 'using']
#
#
# File: Run Jobs at Scale While Optimizing for Cost Using Amazon EC2 Spot Instances with ActionIQ _ ActionIQ Case Study _ AWS.txt
# Keywords: ['actioniq' 'amazon' 'aws' 'business' 'capacity' 'compute' 'costs'
#  'customer' 'customers' 'data' 'ec' 'instances' 'jobs' 'ondemand'
#  'reserved' 'run' 'scale' 'spot' 'using' 'workloads']
#
#
# File: Scaling Text to Image to 100 Million Users Quickly Using Amazon SageMaker _ Canva Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'canva' 'company' 'feature' 'image' 'images' 'ml' 'models'
#  'new' 'pink' 'quickly' 'rekognition' 'sagemaker' 'says' 'scaling'
#  'texttoimage' 'user' 'users' 'using']
#
#
# File: Showpad Accelerates Data Maturity to Unlock Innovation Using Amazon QuickSight _ Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'bi' 'business' 'company' 'customer' 'dashboard'
#  'dashboards' 'data' 'embedded' 'insights' 'minnaert' 'quicksight'
#  'reporting' 'says' 'showpad' 'solution' 'time' 'tools' 'using']
#
#
# File: Vocareum Offers Amazon Lightsail to Help over 50000 Cloud Learners Build Cloud Skills _ Vocareum Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'cloud' 'company' 'education' 'instructors' 'learners'
#  'learning' 'lightsail' 'lin' 'offers' 'resources' 'says' 'skills'
#  'students' 'support' 'training' 'use' 'using' 'vocareum']
#
#
# File: Helping Doctors Treat Pediatric Cancer Using AWS Serverless Services _ Nationwide Childrens Hospital Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'cancer' 'childrens' 'data' 'genomics' 'hospital' 'igm'
#  'institute' 'lammi' 'nationwide' 'nch' 'patients' 'pediatric' 'samples'
#  'serverless' 'services' 'solutions' 'time' 'using']
#
#
# File: How KYTC Transformed the States Customer Experience for 4.1 Million Drivers Using Amazon Connect _ Case Study _ AWS.txt
# Keywords: ['agency' 'agent' 'agents' 'amazon' 'aws' 'center' 'connect' 'contact'
#  'customer' 'customers' 'kentucky' 'kytc' 'minutes' 'new' 'reduced'
#  'service' 'solution' 'time' 'using' 'weeks']
#
#
# File: Greenway Health Scales to Hundreds of Terabytes of Data Using Amazon DocumentDB (with MongoDB compatibility) _ Greenway Health Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'clients' 'company' 'data' 'documentdb' 'ehr' 'greenway'
#  'health' 'healthcare' 'makes' 'new' 'nick' 'says' 'services' 'solution'
#  'solutions' 'storage' 'used' 'using']
#
#
# File: Taggle Systems Case Study _ Amazon Web Services.txt
# Keywords: ['amazon' 'australia' 'aws' 'bowker' 'councils' 'customers' 'data' 'iot'
#  'network' 'platform' 'says' 'scale' 'sensors' 'service' 'solution'
#  'support' 'taggle' 'using' 'utilities' 'water']
#
#
# File: Improving Hiring Diversity and Accelerating App Development on AWS with Branch Insurance _ Case Study _ AWS.txt
# Keywords: ['amazon' 'appsync' 'aws' 'branch' 'building' 'company' 'developers'
#  'development' 'emison' 'hiring' 'insurance' 'just' 'learn' 'quickly'
#  'says' 'serverless' 'services' 'technology' 'use' 'using']
#
#
# File: Game Studio Small Impact Games Runs Successful Alpha and Beta Tests Using Amazon GameLift _ Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'beta' 'company' 'control' 'development' 'game' 'gamelift'
#  'games' 'impact' 'infrastructure' 'marauders' 'sig' 'small' 'solution'
#  'team' 'testing' 'tests' 'using' 'wanted']
#
#
# File: Tempus Ex Case Study _ Amazon ECS _ AWS.txt
# Keywords: ['amazon' 'aws' 'brown' 'cloud' 'company' 'container' 'deploy'
#  'deployments' 'ecs' 'ex' 'hardware' 'manage' 'onpremises' 'says'
#  'service' 'tempus' 'training' 'use' 'using' 'video']
#
#
# File: Lenme builds a secure and reliable lending platform with AWS _ Lenme Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'borrowers' 'cost' 'customers' 'data' 'financial'
#  'identity' 'industry' 'lenders' 'lending' 'lenme' 'lenmes' 'percent'
#  'platform' 'rekognition' 'service' 'services' 'using' 'verification']
#
#
# File: Cognitran Deploys Customized CDN Solution in under 12 Weeks Using Amazon CloudFront.txt
# Keywords: ['amazon' 'aws' 'butterworth' 'cdn' 'cloudfront' 'cognitran' 'company'
#  'content' 'customer' 'customers' 'deliver' 'information' 'new' 'says'
#  'service' 'services' 'software' 'solution' 'technical' 'using']
#
#
# File: High-quality human feedback for your generative AI applications from Amazon SageMaker Ground Truth Plus _ AWS Machine Learning Blog.txt
# Keywords: ['ai' 'amazon' 'annotator' 'content' 'data' 'foundation' 'generative'
#  'ground' 'human' 'image' 'learning' 'machine' 'model' 'models' 'plus'
#  'questions' 'text' 'truth' 'ui' 'video']
#
#
# File: LG AI Research Develops Foundation Model Using Amazon SageMaker _ LG AI Research Case Study _ AWS.txt
# Keywords: ['ai' 'amazon' 'aws' 'data' 'developing' 'exaone' 'fashion' 'foundation'
#  'images' 'infrastructure' 'lg' 'lustre' 'model' 'research' 'sagemaker'
#  'services' 'training' 'used' 'using' 'year']
#
#
# File: Indecomm Case Study _ Amazon Web Services.txt
# Keywords: ['accuracy' 'amazon' 'aws' 'clients' 'data' 'document' 'documents'
#  'extraction' 'idx' 'indecomm' 'indecomms' 'lenders' 'loan' 'manual'
#  'mortgage' 'origination' 'processing' 'solution' 'textract' 'time']
#
#
# File: Mobileye Cuts Costs Using Amazon EC2 _ Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'cloud' 'cluster' 'compute' 'cost' 'data' 'ec' 'instances'
#  'map' 'mobileye' 'performance' 'reisman' 'rem' 'single' 'spot' 'storage'
#  'team' 'using' 'vcpus']
#
#
# File: ADP Developed an Innovative and Secure Digital Wallet in a Few Months Using AWS Services _ Case Study _ AWS.txt
# Keywords: ['access' 'adp' 'amazon' 'aws' 'card' 'customers' 'data' 'digital'
#  'earned' 'financial' 'lambda' 'months' 'nuvalence' 'says' 'security'
#  'service' 'services' 'solution' 'using' 'wallet']
#
#
# File: SecurionPay _ Amazon Redshift _ Amazon Quicksight _ Amazon Kinesis _ AWS.txt
# Keywords: ['amazon' 'aws' 'business' 'customer' 'customers' 'data' 'merchants'
#  'payment' 'payments' 'percent' 'platform' 'process' 'quicksight' 'sales'
#  'secure' 'securionpay' 'services' 'team' 'transactions' 'using']
#
#
# File: Lucid Motors and Zerolight Case Study.txt
# Keywords: ['amazon' 'aws' 'car' 'cloud' 'configurator' 'conversion' 'customer' 'ec'
#  'engagement' 'experience' 'instances' 'launch' 'lucid' 'online'
#  'physical' 'power' 'users' 'using' 'virtual' 'zerolight']
#
#
# File: Deputy Case Study _ Amazon Web Services.txt
# Keywords: ['amazon' 'aurora' 'aws' 'cloud' 'compute' 'data' 'database' 'databases'
#  'deputy' 'deputys' 'engineering' 'performance' 'platform' 'scaling'
#  'scheduling' 'service' 'services' 'shift' 'storage' 'workforce']
#
#
# File: Sprout Social Reduces Costs and Improves Performance Using Amazon EMR _ Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'batch' 'cloud' 'company' 'compute' 'costs' 'data'
#  'elastic' 'emr' 'like' 'processing' 'scale' 'service' 'social' 'solution'
#  'sprout' 'storage' 'team' 'using']
#
#
# File: Amanotes Stays on Beat by Delivering Simple Music Games to Millions Worldwide on AWS.txt
# Keywords: ['amanotes' 'amazon' 'aws' 'business' 'cloudfront' 'content' 'delivering'
#  'elastic' 'game' 'games' 'global' 'kubernetes' 'learn' 'million' 'music'
#  'nghi' 'service' 'services' 'tiles' 'users']
#
#
# File: Deploying and benchmarking YOLOv8 on GPU-based edge devices using AWS IoT Greengrass _ The Internet of Things on AWS  Official Blog.txt
# Keywords: ['aws' 'core' 'device' 'edge' 'export' 'greengrass' 'inference' 'input'
#  'iot' 'machine' 'model' 'models' 'pytorch' 'recomputer' 'run' 'seeed'
#  'step' 'tensorrt' 'using' 'yolov']
#
#
# File: Arm Case Study.txt
# Keywords: ['amazon' 'arm' 'aws' 'characterization' 'cloud' 'compute' 'design' 'ec'
#  'eda' 'environment' 'graviton' 'instances' 'physical' 'says'
#  'scalability' 'spot' 'time' 'turnaround' 'using' 'workloads']
#
#
# File: Building a Scalable Machine Learning Model Monitoring System with DataRobot _ AWS Partner Network (APN) Blog.txt
# Keywords: ['ai' 'amazon' 'aws' 'build' 'code' 'container' 'create' 'data'
#  'datarobot' 'deployment' 'following' 'mlops' 'model' 'models'
#  'monitoring' 'partner' 'sagemaker' 'sqs' 'training' 'ui']
#
#
# File: Helping Fintech Startup Snoop Deploy Quickly and Scale Using Amazon ECS with AWS Fargate _ Case Study _ AWS.txt
# Keywords: ['amazon' 'app' 'applications' 'aws' 'banking' 'building' 'cloud'
#  'compute' 'customers' 'ecs' 'fargate' 'open' 'scale' 'service' 'services'
#  'snoop' 'startup' 'transactions' 'users' 'using']
#
#
# File: Developing a Pioneering Multicancer Early Detection Test _ GRAIL Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'cancer' 'cancers' 'clinical' 'cloud' 'compute' 'cost'
#  'data' 'galleri' 'grail' 'says' 'scale' 'security' 'service' 'services'
#  'storage' 'test' 'uses' 'using']
#
#
# File: ALTBalaji _ Amazon Web Services.txt
# Keywords: ['altbalaji' 'amazon' 'aws' 'content' 'data' 'elemental' 'experience'
#  'indian' 'infrastructure' 'live' 'lock' 'medialive' 'service' 'solution'
#  'streaming' 'streams' 'upp' 'using' 'video' 'viewers']
#
#
# File: Measurable-AI-case-study.txt
# Keywords: ['ai' 'alternative' 'amazon' 'aws' 'customers' 'data' 'developers'
#  'insights' 'kubernetes' 'lau' 'managed' 'measurable' 'opensearch'
#  'provider' 'query' 'service' 'services' 'startup' 'storage' 'time']
#
#
# File: Spryker Case Study _ Amazon Elastic Compute Cloud _ AWS.txt
# Keywords: ['amazon' 'aws' 'businesses' 'cloud' 'commerce' 'compute' 'customer'
#  'customers' 'days' 'global' 'lunov' 'meet' 'onboarding' 'provides'
#  'scale' 'services' 'solution' 'solutions' 'spryker' 'using']
#
#
# File: Increasing Scalability and Data Durability of Television Voting Solution Using Amazon MemoryDB for Redis with Mediaset _ Mediaset Case Study _ AWS.txt
# Keywords: ['amazon' 'amici' 'aws' 'company' 'finale' 'mediaset' 'memorydb' 'million'
#  'onpremises' 'redis' 'says' 'services' 'solution' 'television' 'time'
#  'traffic' 'using' 'viewers' 'votes' 'voting']
#
#
# File: Shgardi Case Study.txt
# Keywords: ['amazon' 'aws' 'company' 'costs' 'customers' 'dahab' 'delivery'
#  'infrastructure' 'new' 'percent' 'personalize' 'platform' 'says' 'scale'
#  'servers' 'service' 'services' 'shgardi' 'used' 'using']
#
#
# File: Deploy a serverless ML inference endpoint of large language models using FastAPI AWS Lambda and AWS CDK _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'api' 'artifacts' 'aws' 'cdk' 'code' 'contains' 'deploy'
#  'docker' 'following' 'inference' 'lambda' 'make' 'ml' 'model' 'python'
#  'run' 'solution' 'use' 'using']
#
#
# File: Generating 100000 Images Daily Using Amazon ECS _ Scenario Case Study _ AWS.txt
# Keywords: ['ai' 'amazon' 'artists' 'assets' 'aws' 'batch' 'cdk' 'company'
#  'development' 'game' 'generate' 'generative' 'images' 'months' 'nivon'
#  'says' 'scenario' 'service' 'time' 'using']
#
#
# File: The Mill Adventure Case Study.txt
# Keywords: ['adventure' 'adventures' 'amazon' 'arruda' 'aws' 'customer' 'customers'
#  'data' 'igaming' 'industry' 'new' 'platform' 'player' 'players'
#  'regulations' 'says' 'serverless' 'service' 'services' 'using']
#
#
# File: Comscore Maintains Privacy While Cross-Analyzing Data using AWS Clean Rooms _ Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'clean' 'collaborators' 'comscore' 'customers' 'data'
#  'environment' 'information' 'insights' 'learn' 'media' 'partners'
#  'privacy' 'provide' 'rooms' 'service' 'solution' 'storage' 'using']
#
#
# File: Isetan Mitsukoshi System Solutions seamlessly migrates databases to Amazon Aurora using Amazon DMA _ Isetan Mitsukoshi System Solutions Case Study _ AWS.txt
# Keywords: ['amazon' 'aurora' 'aws' 'cloud' 'database' 'databases' 'department'
#  'digital' 'dma' 'dx' 'help' 'ims' 'isetan' 'migrate' 'migration'
#  'mitsukoshi' 'oracle' 'service' 'services' 'solutions']
#
#
# File: Migrating Large-Scale SAP Workloads Seamlessly to AWS with Sony _ Sony Case Study _ AWS.txt
# Keywords: ['amazon' 'applications' 'aws' 'business' 'cloud' 'data' 'enterprise'
#  'giscin' 'infrastructure' 'migration' 'percent' 'platform' 'project'
#  'sap' 'service' 'services' 'sony' 'support' 'west' 'workloads']
#
#
# File: Introducing popularity tuning for Similar-Items in Amazon Personalize _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'aws' 'dataset' 'discount' 'item' 'items' 'movie' 'personalize'
#  'popular' 'popularity' 'rank' 'recipe' 'recommendations' 'recommended'
#  'similar' 'similaritems' 'tune' 'tuning' 'users' 'value']
#
#
# File: Mobiuspace delivers up to 40 improved price-performance using Amazon EMR on EKS and Graviton instance _ Mobiuspace Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'better' 'big' 'content' 'data' 'ec' 'eks' 'emr'
#  'instances' 'machine' 'mobiuspace' 'recommendation' 'sagemaker' 'service'
#  'services' 'technology' 'user' 'users' 'video']
#
#
# File: Scaling Sustainability Solutions for Buildings Using AWS with BrainBox AI _ Case Study _ AWS.txt
# Keywords: ['ai' 'amazon' 'aws' 'brainbox' 'building' 'buildings' 'data' 'emissions'
#  'energy' 'hvac' 'ml' 'new' 'reduce' 'regions' 'scale' 'services'
#  'solution' 'solutions' 'technology' 'using']
#
#
# File: Relay Therapeutics Case Study.txt
# Keywords: ['amazon' 'analysis' 'aws' 'batch' 'billion' 'billions' 'cloud' 'company'
#  'compounds' 'compute' 'costs' 'data' 'ec' 'instances' 'relay' 'run'
#  'scientists' 'spot' 'therapeutics' 'using']
#
#
# File: Insightful.Mobi Decreases Costs and Enhances Dashboard Performance Using Amazon QuickSight _ Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'business' 'consumer' 'customer' 'customers' 'dashboards'
#  'data' 'goods' 'insightfulmobi' 'insights' 'miller' 'new' 'quicksight'
#  'reports' 'sales' 'says' 'tools' 'used' 'using']
#
#
# File: Accelerate Time to Business Value Using Amazon SageMaker at Scale with NatWest Group _ Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'bank' 'build' 'business' 'data' 'environment' 'group'
#  'ml' 'natwest' 'sagemaker' 'science' 'service' 'services' 'solutions'
#  'teams' 'time' 'use' 'using' 'value']
#
#
# File: Kirana Megatara Reduces Procurement Costs by 10 Percent for Raw Rubber with Speedy Reporting on AWS _ Case Study _ AWS.txt
# Keywords: ['adinugraha' 'amazon' 'analytics' 'aws' 'business' 'cloud' 'data'
#  'department' 'kirana' 'megatara' 'procurement' 'production' 'quicksight'
#  'raw' 'reports' 'rubber' 'sap' 'says' 'suppliers' 'time']
#
#
# File: How Earth.com and Provectus implemented their MLOps Infrastructure with Amazon SageMaker _ AWS Machine Learning Blog.txt
# Keywords: ['ai' 'amazon' 'data' 'earthcom' 'earthsnap' 'image' 'infrastructure'
#  'managed' 'ml' 'mlops' 'model' 'models' 'new' 'provectus' 'recognition'
#  'run' 'sagemaker' 'solution' 'training' 'using']
#
#
# File: Improving Transportation with Mobility Data Using Amazon EMR and Serverless Managed Services _ Arity Case Study _ AWS.txt
# Keywords: ['amazon' 'analytics' 'apache' 'architecture' 'arity' 'aws' 'business'
#  'company' 'costs' 'data' 'driving' 'emr' 'infrastructure' 'managed'
#  'services' 'solution' 'streaming' 'use' 'uses' 'using']
#
#
# File: SURF Drives Ground-Breaking Research Accelerates Time to Insight Using AWS.txt
# Keywords: ['amazon' 'aws' 'best' 'cloud' 'compute' 'data' 'ec' 'education'
#  'learning' 'machine' 'new' 'project' 'projects' 'research' 'researchers'
#  'service' 'services' 'surf' 'team' 'using']
#
#
# File: Illumina Reduced Carbon Emissions by 89 and Lowered Data Storage Costs Using AWS _ Illumina Case Study _ AWS.txt
# Keywords: ['access' 'amazon' 'analysis' 'aws' 'carbon' 'class' 'cost' 'costs'
#  'customers' 'data' 'emissions' 'footprint' 'illumina' 'illuminas'
#  'intelligenttiering' 'percent' 'reduce' 'savings' 'storage' 'using']
#
#
# File: LetsGetChecked Case Study _ Amazon Connect _ AWS Lex.txt
# Keywords: ['amazon' 'aws' 'business' 'care' 'company' 'companys' 'connect'
#  'customer' 'data' 'health' 'healthcare' 'integration' 'interactions'
#  'letsgetchecked' 'manage' 'management' 'people' 'solutions' 'testing'
#  'using']
#
#
# File: Prima Group Case Study.txt
# Keywords: ['amazon' 'aws' 'company' 'content' 'czech' 'group' 'growth' 'iprima'
#  'kouimsk' 'kubernetes' 'managed' 'platform' 'prima' 'scale' 'service'
#  'services' 'streaming' 'support' 'tv' 'using']
#
#
# File: N KID Group Case Study  Amazon Web Services (AWS).txt
# Keywords: ['amazon' 'aws' 'beanstalk' 'cloud' 'database' 'digital' 'elastic'
#  'experience' 'group' 'journey' 'khoa' 'kid' 'kids' 'play' 'promotions'
#  'server' 'service' 'services' 'sql' 'using']
#
#
# File: Introducing the latest Machine Learning Lens for the AWS Well-Architected Framework _ AWS Architecture Blog.txt
# Keywords: ['architecture' 'aws' 'best' 'business' 'customers' 'data' 'framework'
#  'learning' 'lens' 'lifecycle' 'machine' 'ml' 'model' 'new' 'pillars'
#  'practices' 'services' 'solutions' 'wellarchitected' 'workloads']
#
#
# File: Scaling to Ingest 250 TB from 1 TB Daily Using Amazon Kinesis Data Streams with LaunchDarkly _ LaunchDarkly Case Study _ AWS.txt
# Keywords: ['amazon' 'analytics' 'availability' 'aws' 'customers' 'data' 'feature'
#  'flags' 'kinesis' 'launchdarkly' 'risk' 'says' 'scale' 'service'
#  'services' 'software' 'streams' 'use' 'using' 'zorn']
#
#
# File: Building a medical image search platform on AWS _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'amplify' 'aws' 'bucket' 'cloudformation' 'container' 'data'
#  'deploy' 'following' 'image' 'images' 'learning' 'medical' 'model'
#  'search' 'solution' 'stack' 'text' 'use' 'using']
#
#
# File: Enhancing customer experience using Amazon CloudFront with Zalando _ Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'cloudfront' 'content' 'customer' 'customers' 'developer'
#  'experience' 'flexibility' 'functions' 'lambdaedge' 'management' 'media'
#  'migration' 'online' 'performance' 'service' 'solution' 'using' 'zalando']
#
#
# File: Streamline Workflows Using the AWS Support App in Slack with Okta _ Okta Case Study _ AWS.txt
# Keywords: ['access' 'app' 'application' 'aws' 'company' 'console' 'create'
#  'customer' 'engineers' 'faster' 'identity' 'management' 'okta' 'oktas'
#  'resolve' 'slack' 'support' 'team' 'ticket' 'using']
#
#
# File: Deploy Falcon-40B with large model inference DLCs on Amazon SageMaker _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'aws' 'code' 'dlcs' 'endpoint' 'falconb' 'gpus' 'host' 'hosting'
#  'import' 'inference' 'large' 'learning' 'llm' 'lmi' 'model' 'models'
#  'sagemaker' 'use' 'using']
#
#
# File: How BrainPad fosters internal knowledge sharing with Amazon Kendra _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'brainpad' 'chatbot' 'cost' 'data' 'employees' 'experience'
#  'implementation' 'information' 'internal' 'kendra' 'knowledge' 'lambda'
#  'search' 'searchability' 'sharing' 'tool' 'use' 'user' 'using']
#
#
# File: Valant Uses AWS Communication Developer Services to Help Behavioral Health Practices Drive Better Patient Engagement _ Valant Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'behavioral' 'capabilities' 'communication'
#  'communications' 'engagement' 'health' 'jay' 'new' 'patient' 'patients'
#  'practices' 'reminders' 'services' 'solution' 'solutions' 'telehealth'
#  'valant' 'video']
#
#
# File: Delivering Travel Deals across 110 Markets Using Amazon CloudFront with Skyscanner _ Case Study _ AWS.txt
# Keywords: ['amazon' 'applications' 'aws' 'cdk' 'cdn' 'cloud' 'cloudfront' 'company'
#  'global' 'handler' 'high' 'learn' 'says' 'serverless' 'services' 'shield'
#  'skyscanner' 'team' 'travel' 'using']
#
#
# File: Yamato Logistics (HK) case study.txt
# Keywords: ['amazon' 'athena' 'aws' 'business' 'company' 'create' 'dashboards' 'data'
#  'hk' 'logistics' 'quicksight' 'samson' 'serverless' 'service' 'services'
#  'solution' 'storage' 'using' 'visibility' 'yamato']
#
#
# File: TEG on using Machine Learning and Amazon Personalize to boost user engagement and ticket sales _ Ticketek Video _ AWS.txt
# Keywords: ['amazon' 'aws' 'company' 'cto' 'events' 'journey' 'learning' 'machine'
#  'officer' 'percent' 'personalize' 'purchases' 'sales' 'services' 'tane'
#  'technology' 'teg' 'ticketing' 'tickets' 'using']
#
#
# File: Democratize Access to HPC for Computer-Aided Materials Design Using Amazon EC2 Spot Instances with Good Chemistry _ Good Chemistry Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'chemical' 'chemistry' 'cloud' 'computing' 'development'
#  'good' 'hpc' 'kubernetes' 'million' 'new' 'pfas' 'qemist' 'run' 'says'
#  'scale' 'simulations' 'solution' 'using']
#
#
# File: 36 new or updated datasets on the Registry of Open Data_ AI analysis-ready datasets and more _ AWS Public Sector Blog.txt
# Keywords: ['ai' 'amazon' 'available' 'aws' 'brain' 'cancer' 'data' 'dataset'
#  'datasets' 'nasa' 'national' 'new' 'open' 'program' 'public' 'registry'
#  'research' 'sector' 'university' 'updated']
#
#
# File: InMotion Inovasi Teknologi Boosts Local-Language Engagement with Millions of Indonesians on AWS _ Case Study _ AWS.txt
# Keywords: ['amazon' 'application' 'applications' 'aws' 'business' 'chatbot' 'cloud'
#  'cloudfront' 'costs' 'customer' 'dolphins' 'ec' 'hastomo' 'indonesia'
#  'inmotion' 'millions' 'performance' 'service' 'srm' 'teknologi']
#
#
# File: What Will Generative AI Mean for Your Business_ _ AWS Cloud Enterprise Strategy Blog.txt
# Keywords: ['agility' 'ai' 'amazon' 'applications' 'aws' 'business' 'capabilities'
#  'cloud' 'companies' 'competitive' 'customers' 'data' 'generative' 'ideas'
#  'innovation' 'models' 'new' 'processes' 'services' 'use']
#
#
# File: Toppan Case Study.txt
# Keywords: ['aws' 'business' 'center' 'certification' 'cloud' 'course' 'development'
#  'digital' 'division' 'dx' 'employees' 'hr' 'learn' 'printing' 'says'
#  'services' 'skills' 'toppan' 'training' 'using']
#
#
# File: Tokenize Builds A Scalable Cost-Effective Digital Exchange Platform On AWS _ Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'cloud' 'cost' 'customer' 'digital' 'exchange'
#  'infrastructure' 'learn' 'malaysia' 'percent' 'performance' 'platform'
#  'route' 'service' 'services' 'startup' 'tokenize' 'users' 'virtual']
#
#
# File: Reaching Remote Learners Globally Using Amazon CloudFront _ Doping Hafiza Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'cloudfront' 'company' 'content' 'data' 'delivery'
#  'different' 'doping' 'educational' 'hafiza' 'learners' 'learning'
#  'service' 'services' 'storage' 'students' 'sufle' 'using' 'video']
#
#
# File: Streamline and Standardize the Complete ML Lifecycle Using Amazon SageMaker with Thomson Reuters _ Thomson Reuters Case Study _ AWS.txt
# Keywords: ['ai' 'amazon' 'aws' 'business' 'company' 'data' 'enterprise' 'ml' 'model'
#  'models' 'platform' 'reuters' 'sagemaker' 'services' 'solution'
#  'solutions' 'thomson' 'tr' 'use' 'using']
#
#
# File: Boehringer Ingelheim Establishes Data-Driven Foundations Using AWS to Accelerate the Launch of New Medicines _ Boehringer Ingelheim Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'boehringer' 'company' 'compliance' 'data' 'datadriven'
#  'dataland' 'development' 'employees' 'henrich' 'ingelheim' 'initiative'
#  'says' 'service' 'services' 'solution' 'use' 'using' 'working']
#
#
# File: MARVEL SNAP_ How Second Dinner and Nuverse Built and Scaled the Mobile Game of the Year Using AWS for Games _ Case Study _ AWS.txt
# Keywords: ['amazon' 'architecture' 'aws' 'developers' 'dinner' 'features' 'game'
#  'gamelift' 'games' 'marvel' 'millions' 'nuverse' 'players' 'says'
#  'second' 'serverless' 'service' 'services' 'snap' 'using']
#
#
# File: BNS Group Case Study _ Amazon Web Services.txt
# Keywords: ['amazon' 'analytics' 'aws' 'bns' 'buchanan' 'clients' 'cloud' 'customer'
#  'data' 'group' 'isv' 'learn' 'migration' 'program' 'server' 'sms'
#  'software' 'solutions' 'sql' 'technical']
#
#
# File: Exploring Generative AI in conversational experiences_ An Introduction with Amazon Lex Langchain and SageMaker Jumpstart _ AWS Machine Learning Blog.txt
# Keywords: ['ai' 'amazon' 'aws' 'bot' 'choose' 'conversation' 'following' 'function'
#  'history' 'lambda' 'langchain' 'learning' 'lex' 'llm' 'memory' 'qnabot'
#  'sagemaker' 'session' 'solution' 'user']
#
#
# File: Safe image generation and diffusion models with Amazon AI content moderation services _ AWS Machine Learning Blog.txt
# Keywords: ['ai' 'amazon' 'api' 'aws' 'comprehend' 'content' 'diffusion' 'image'
#  'images' 'input' 'model' 'moderate' 'moderation' 'prompts' 'rekognition'
#  'sagemaker' 'solution' 'stable' 'text' 'using']
#
#
# File: Bazaarvoice Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'bazaarvoice' 'clients' 'company' 'content' 'costs'
#  'deploy' 'inference' 'kratz' 'minutes' 'ml' 'model' 'models' 'new'
#  'sagemaker' 'says' 'scale' 'serverless' 'using']
#
#
# File: Actuate AI Case study.txt
# Keywords: ['actuate' 'ai' 'amazon' 'aws' 'camera' 'clients' 'cloud' 'compute'
#  'computing' 'ec' 'enabled' 'expensive' 'instances' 'power' 'recognition'
#  'says' 'security' 'time' 'using' 'ziomek']
#
#
# File: FanCode Case Study - Amazon Web Services (AWS).txt
# Keywords: ['amazon' 'aws' 'best' 'cloud' 'content' 'dream' 'fancode' 'features'
#  'increase' 'infrastructure' 'live' 'million' 'new' 'platform' 'services'
#  'sports' 'streams' 'team' 'users' 'video']
#
#
# File: Building generative AI applications for your startup part 1 _ AWS Startups Blog.txt
# Keywords: ['ai' 'application' 'applications' 'aws' 'based' 'build' 'components'
#  'data' 'figure' 'foundation' 'generate' 'generative' 'learning' 'model'
#  'models' 'prompt' 'startups' 'technique' 'tools' 'using']
#
#
# File: Windsor.txt
# Keywords: ['amazon' 'availability' 'aws' 'brokers' 'cloud' 'company' 'customers'
#  'data' 'infrastructure' 'migration' 'petsas' 'platform' 'says' 'service'
#  'services' 'time' 'trading' 'use' 'using' 'windsor']
#
#
# File: BIPO Improves Customer Experience on its HR Management System Using Machine Learning on AWS _ Case Study _ AWS.txt
# Keywords: ['access' 'amazon' 'attendancetaking' 'aws' 'bipo' 'claims' 'customers'
#  'employees' 'facial' 'feature' 'features' 'hr' 'hrms' 'management'
#  'percent' 'platform' 'recognition' 'recognitionbased' 'solutions' 'using']
#
#
# File: EPAM Systems.txt
# Keywords: ['amazon' 'applications' 'aws' 'cloud' 'compute' 'customers' 'ec' 'epam'
#  'faster' 'graviton' 'isaiev' 'learn' 'maestro' 'percent' 'performance'
#  'platform' 'says' 'services' 'team' 'using']
#
#
# File: Dallara Uses HPC on AWS to Off-Load Peak CFD Workloads for Race Car Simulations _ Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'cars' 'cfd' 'cloud' 'company' 'dallara' 'ec' 'formula'
#  'hpc' 'lustre' 'needed' 'onpremises' 'premises' 'says' 'serioli'
#  'solution' 'use' 'using' 'workflow']
#
#
# File: Queensland University of Technology Advances Global Research on Rare Diseases Using the AWS Cloud.txt
# Keywords: ['amazon' 'aws' 'care' 'clinical' 'cloud' 'data' 'digital' 'eresearch'
#  'eresearchqut' 'health' 'platform' 'queensland' 'registry' 'research'
#  'security' 'service' 'team' 'technology' 'trrf' 'university']
#
#
# File: Using Amazon SageMaker to improve response time of its demand forecast service by 200 percent _ Visualfabriq Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'company' 'customer' 'customers' 'data' 'deployment'
#  'improved' 'intelligence' 'management' 'ml' 'model' 'models'
#  'performance' 'revenue' 'sagemaker' 'service' 'solution' 'using'
#  'visualfabriq']
#
#
# File: AWS Customer Case Study _ Kepler Provides Effective Monitoring of Elderly Care Home Residents Using AWS _ AWS.txt
# Keywords: ['amazon' 'aws' 'care' 'ecs' 'edge' 'elderly' 'homes' 'kepler' 'night'
#  'nurse' 'residents' 'service' 'services' 'solution' 'staff' 'stokman'
#  'training' 'using' 'video' 'vision']
#
#
# File: How AWS is helping thredUP revolutionize the resale model for brands _ AWS for Industries.txt
# Keywords: ['able' 'amazon' 'aws' 'brands' 'customers' 'data' 'industry' 'market'
#  'percent' 'products' 'provide' 'raas' 'resale' 'retail' 'retailers'
#  'secondhand' 'security' 'services' 'thredup' 'thredups']
#
#
# File: e-banner Streamlines Its Contact Center Operations and Facilitates a Fully Remote Workforce with Amazon Connect _ e-banner Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'center' 'cloud' 'connect' 'contact' 'customer'
#  'customers' 'ebanner' 'ebanners' 'experience' 'ivr' 'kenny' 'megazone'
#  'seamless' 'service' 'services' 'solution' 'team' 'work']
#
#
# File: Buildigo.txt
# Keywords: ['amazon' 'aws' 'buildigo' 'company' 'craftspeople' 'customer' 'customers'
#  'data' 'demand' 'development' 'easy' 'feature' 'platform' 'scale'
#  'service' 'services' 'team' 'technology' 'using' 'work']
#
#
# File: Interactively fine-tune Falcon-40B and other LLMs on Amazon SageMaker Studio notebooks using QLoRA _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'aws' 'clay' 'face' 'finetune' 'finetuning' 'hugging' 'install'
#  'instance' 'llms' 'model' 'models' 'notebook' 'notebooks' 'richie'
#  'sagemaker' 'studio' 'tensorboard' 'use' 'using']
#
#
# File: Reducing Infrastructure Costs by 66 by Migrating to AWS with SilverBlaze _ SilverBlaze Case Study _ AWS.txt
# Keywords: ['application' 'atayo' 'aws' 'center' 'company' 'costs' 'customers'
#  'harris' 'infrastructure' 'migrating' 'migration' 'performance' 'says'
#  'scalability' 'servers' 'service' 'services' 'silverblaze' 'time' 'using']
#
#
# File: FLSmidth Case Study.txt
# Keywords: ['amazon' 'aws' 'capacity' 'cement' 'cloud' 'company' 'compute'
#  'computing' 'cpfd' 'ec' 'flsmidth' 'hpc' 'nvidia' 'reactor' 'run'
#  'services' 'simulations' 'technology' 'using' 'virtual']
#
#
# File: Improving Operational Efficiency with Predictive Maintenance Using Amazon Monitron _ Baxter Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'baxter' 'critical' 'data' 'downtime' 'equipment'
#  'facilities' 'machine' 'maintenance' 'manufacturing' 'ml' 'monitron'
#  'operations' 'predictive' 'sensors' 'solution' 'technicians' 'unplanned'
#  'using']
#
#
# File: Power recommendations and search using an IMDb knowledge graph  Part 3 _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'app' 'aws' 'catalog' 'create' 'data' 'following' 'graph' 'imdb'
#  'index' 'kg' 'knn' 'knowledge' 'lambda' 'ooc' 'opensearch' 'search'
#  'service' 'text' 'using']
#
#
# File: Red Canary Architects for Fault Tolerance and Saves up to 80 Using Amazon EC2 Spot Instances _ Red Canary Case Study _ AWS.txt
# Keywords: ['amazon' 'architecture' 'aws' 'canary' 'cloud' 'company' 'compute'
#  'costs' 'data' 'ec' 'eks' 'instances' 'kubernetes' 'processing' 'red'
#  'service' 'services' 'solution' 'spot' 'using']
#
#
# File: Security Posture Strengthened Using AWS Shield Advanced with OutSystems _ Case Study _ AWS.txt
# Keywords: ['advanced' 'antunes' 'application' 'applications' 'aws' 'company'
#  'customers' 'firewall' 'manager' 'outsystems' 'protection' 'rules' 'says'
#  'security' 'services' 'shield' 'solution' 'using' 'waf' 'web']
#
#
# File: Indivumed Case Study.txt
# Keywords: ['amazon' 'aws' 'cancer' 'capacity' 'clinical' 'cluster' 'compute' 'data'
#  'elastic' 'indivumed' 'indivutype' 'multiomics' 'new' 'percent'
#  'processing' 'research' 'samples' 'service' 'treatments' 'using']
#
#
# File: CloudWave Modernizes EHR Disaster Recovery and Provides Fast Secure Access to Archived Imaging Data on AWS _ Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'cloud' 'cloudwave' 'company' 'customers' 'data'
#  'disaster' 'donahue' 'ehr' 'glacier' 'healthcare' 'recovery' 'retrieval'
#  'says' 'security' 'service' 'services' 'storage' 'time']
#
#
# File: CaratLane Case Study - Amazon Web Services (AWS).txt
# Keywords: ['amazon' 'applications' 'aws' 'caratlane' 'cloud' 'customer' 'data'
#  'database' 'ec' 'elastic' 'experience' 'improve' 'infrastructure'
#  'jewelry' 'ml' 'scale' 'seasonal' 'secure' 'service' 'use']
#
#
# File: Lyell GxP Compliance _ Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'changes' 'cloud' 'compliance' 'data' 'lyell' 'managed'
#  'new' 'rapid' 'run' 'service' 'services' 'simple' 'stein' 'systems'
#  'time' 'using' 'validate' 'validation']
#
#
# File: 6sense Case Study.txt
# Keywords: ['amazon' 'aws' 'cloud' 'clusters' 'company' 'data' 'ec' 'eks' 'insights'
#  'kubernetes' 'managed' 'run' 'says' 'sense' 'service' 'solution' 'speed'
#  'support' 'using' 'workloads']
#
#
# File: Volkswagen Passenger Cars Case Study.txt
# Keywords: ['applications' 'aws' 'cae' 'cars' 'cloud' 'data' 'dcv' 'engineers'
#  'flexibility' 'home' 'mayer' 'nice' 'passenger' 'remote' 'says'
#  'simulations' 'streaming' 'using' 'volkswagen' 'workstations']
#
#
# File: Toyota Motor North America Case Study _ AWS.txt
# Keywords: ['amazon' 'application' 'applications' 'aws' 'backstage' 'build' 'chofer'
#  'cloud' 'company' 'cost' 'developers' 'development' 'motor' 'service'
#  'services' 'team' 'teams' 'tmna' 'toyota' 'using']
#
#
# File: Empowering Customers to Take an Active Role in the Energy Transition Using AWS Serverless Services with Iberdrola _ Case Study _ AWS.txt
# Keywords: ['amazon' 'asa' 'aws' 'company' 'consumption' 'customers' 'devices'
#  'energy' 'global' 'help' 'iberdrola' 'platform' 'reduce' 'serverless'
#  'service' 'services' 'smart' 'solution' 'use' 'using']
#
#
# File: Snap optimizes cost savings with Amazon S3 Glacier Instant Retrieval _ Snap Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'company' 'content' 'cost' 'data' 'glacier' 'instant'
#  'manoharan' 'media' 'migrated' 'performance' 'retrieval' 'says' 'service'
#  'snap' 'snapchat' 'storage' 'storing' 'using']
#
#
# File: Generative AI for Telcos_ taking customer experience and productivity to the next level _ AWS for Industries.txt
# Keywords: ['ai' 'amazon' 'aws' 'ceos' 'chris' 'costs' 'customer' 'customers' 'data'
#  'gartner' 'generative' 'instances' 'learning' 'mark' 'models' 'potential'
#  'productivity' 'technology' 'telcos' 'use']
#
#
# File: Accelerating Migration at Scale Using AWS Application Migration Service with 3M Company _ Case Study _ AWS.txt
# Keywords: ['application' 'applications' 'aws' 'cloud' 'company' 'compute' 'data'
#  'enterprise' 'hammer' 'migrated' 'migration' 'months' 'professional'
#  'says' 'scale' 'service' 'services' 'solution' 'using' 'workloads']
#
#
# File: Information Technology Institute Launches Postgraduate Artificial Intelligence Diploma Using AWS _ Case Study _ AWS.txt
# Keywords: ['academy' 'ai' 'aipro' 'aws' 'certification' 'cloud' 'diploma'
#  'education' 'egypt' 'information' 'institute' 'iti' 'new' 'program'
#  'programs' 'services' 'skills' 'students' 'training' 'used']
#
#
# File: Help Customers Reduce Data Query Time by 70 and Improve Business Insights Capabilities with Amazon OpenSearch Service _ Deputy Case Study _ AWS.txt
# Keywords: ['amazon' 'application' 'aws' 'business' 'customers' 'data' 'deputy'
#  'insights' 'marchant' 'millions' 'opensearch' 'performance' 'says'
#  'scale' 'scheduling' 'service' 'software' 'time' 'times' 'use']
#
#
# File: Sixth Force Solutions _ Amazon Web Services.txt
# Keywords: ['amazon' 'application' 'architect' 'aws' 'cloud' 'customers' 'enterprise'
#  'force' 'nizam' 'prolaborate' 'saas' 'says' 'service' 'sixth' 'software'
#  'solutions' 'sparx' 'streaming' 'version' 'versions']
#
#
# File: Directing ML-powered Operational Insights from Amazon DevOps Guru to your Datadog event stream _ AWS DevOps Blog.txt
# Keywords: ['amazon' 'application' 'aws' 'cli' 'create' 'datadog' 'deploy' 'devops'
#  'events' 'functions' 'guru' 'insight' 'insights' 'key' 'lambda' 'new'
#  'sam' 'secret' 'serverless' 'stack']
#
#
# File: Botprise Reduces Time to Remediation by 86 on Average Using Automation and AWS Security Hub _ Botprise Case Study _ AWS.txt
# Keywords: ['amazon' 'automation' 'aws' 'botprise' 'bulusu' 'cloud' 'company'
#  'customers' 'growth' 'hub' 'issues' 'operations' 'posture' 'remediation'
#  'scale' 'security' 'services' 'solution' 'time' 'using']
#
#
# File: Central East Ontario Hospital Partnership Launches a Clinical Information System in the AWS Cloud _ Case Study _ AWS.txt
# Keywords: ['alternate' 'amazon' 'aws' 'care' 'cehc' 'cis' 'clinical' 'cloud' 'cost'
#  'data' 'environment' 'health' 'healthcare' 'hospital' 'information'
#  'patients' 'regional' 'says' 'services' 'solution']
#
#
# File: Midtrans Case Study _ Amazon Web Services.txt
# Keywords: ['amazon' 'aws' 'businesses' 'cloud' 'companies' 'digital' 'eizel'
#  'indonesia' 'midtrans' 'partners' 'payment' 'pojok' 'portal' 'products'
#  'service' 'services' 'smbs' 'storage' 'transformation' 'usaha']
#
#
# File: THREAD _ Life Sciences _ AWS.txt
# Keywords: ['amazon' 'aws' 'clinical' 'cloud' 'customers' 'data' 'global' 'help'
#  'participants' 'platform' 'provides' 'research' 'says' 'service'
#  'services' 'studies' 'thread' 'trial' 'trials' 'using']
#
#
# File: Creating an Optimized Solution for Smart Buildings Using Amazon EC2 G5g Instances with Mircoms OpenGN _ Case Study _ AWS.txt
# Keywords: ['alarm' 'amazon' 'application' 'aws' 'building' 'cloud' 'costs' 'deliver'
#  'ec' 'gg' 'graviton' 'infrastructure' 'instances' 'mircom' 'opengn'
#  'performance' 'smart' 'solution' 'technologies' 'using']
#
#
# File: AEON Case Study.txt
# Keywords: ['aeon' 'amazon' 'aws' 'card' 'cloud' 'customers' 'data' 'industry'
#  'infrastructure' 'meet' 'migration' 'new' 'payment' 'peaks' 'processing'
#  'scale' 'services' 'support' 'traffic' 'using']
#
#
# File: Create high-quality images with Stable Diffusion models and deploy them cost-efficiently with Amazon SageMaker _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'create' 'data' 'diffusion' 'following' 'image' 'images'
#  'inference' 'input' 'mme' 'model' 'models' 'prompt' 'python' 'sagemaker'
#  'stable' 'text' 'triton' 'use' 'using']
#
#
# File: Wave Commerce case study.txt
# Keywords: ['amazon' 'aws' 'clients' 'commerce' 'company' 'compute' 'customers'
#  'development' 'ecommerce' 'experiences' 'lambda' 'management' 'range'
#  'resources' 'says' 'serverless' 'services' 'shopify' 'solutions' 'wave']
#
#
# File: Helen of Troy Case Study _ Consumer Packaged Goods _ AWS.txt
# Keywords: ['app' 'aws' 'braun' 'built' 'company' 'core' 'customer' 'customers'
#  'data' 'devices' 'experience' 'helen' 'innovation' 'iot' 'products'
#  'professional' 'services' 'solution' 'troy' 'using']
#
#
# File: Revolutionizing Manufacturing with Sphere and Amazon Lookout for Visions XR and AI Integration _ AWS Partner Network (APN) Blog.txt
# Keywords: ['ai' 'amazon' 'aws' 'customers' 'integration' 'lookout' 'machine'
#  'manufacturing' 'micron' 'models' 'operator' 'partner' 'solution'
#  'sphere' 'spheres' 'train' 'training' 'use' 'vision' 'xr']
#
#
# File: Which Recurring Business Processes Can Small and Medium Businesses Automate_ _ AWS Smart Business Blog.txt
# Keywords: ['ai' 'amazon' 'automation' 'aws' 'bpa' 'business' 'businesses' 'customer'
#  'data' 'efficiency' 'experience' 'help' 'improve' 'marketing' 'process'
#  'reports' 'resources' 'smbs' 'solutions' 'use']
#
#
# File: Kee Wah Bakery Brings Timeless Baked Goods to Modern Shoppers with Eshop on AWS _ Kee Wah Bakery Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'bakery' 'cloud' 'customers' 'ecommerce' 'elastic' 'eshop'
#  'hong' 'kee' 'kong' 'lau' 'nextlink' 'online' 'performance' 'sales'
#  'site' 'traffic' 'wah' 'website']
#
#
# File: Reinventing the data experience_ Use generative AI and modern data architecture to unlock insights _ AWS Machine Learning Blog.txt
# Keywords: ['ai' 'amazon' 'architecture' 'aws' 'catalog' 'chain' 'data' 'database'
#  'databases' 'employees' 'following' 'generative' 'langchain' 'llm'
#  'models' 'prompt' 'query' 'sql' 'table' 'user']
#
#
# File: Reducing Time to Results Carbon Footprint and Cost Using AWS HPC _ Baker Hughes Case Study _ AWS.txt
# Keywords: ['amazon' 'ansys' 'aws' 'baker' 'capacity' 'carbon' 'cloud' 'compute' 'ec'
#  'engineers' 'footprint' 'hpc' 'hughes' 'instances' 'percent'
#  'performance' 'run' 'solution' 'time' 'using']
#
#
# File: Return Entertainment Case Study.txt
# Keywords: ['amazon' 'aws' 'cloud' 'cloudnative' 'company' 'compute' 'development'
#  'ec' 'entertainment' 'game' 'games' 'gaming' 'needed' 'return' 'says'
#  'serverless' 'service' 'services' 'solutions' 'using']
#
#
# File: Accelerating Time to Market Using AWS and AWS Partner AccelByte _ Omeda Studios Case Study _ AWS.txt
# Keywords: ['accelbyte' 'amazon' 'aws' 'backend' 'game' 'miles' 'needed' 'omeda'
#  'player' 'players' 'predecessor' 'says' 'scalable' 'scale' 'service'
#  'services' 'studio' 'studios' 'time' 'using']
#
#
# File: Announcing enhanced table extractions with Amazon Textract _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'api' 'block' 'cash' 'code' 'data' 'document' 'documents'
#  'extract' 'feature' 'following' 'footers' 'information' 'new' 'table'
#  'tables' 'textract' 'textractor' 'title' 'use']
#
#
# File: How Generative AI will transform manufacturing _ AWS for Industries.txt
# Keywords: ['ai' 'amazon' 'aws' 'bedrock' 'chain' 'customers' 'data' 'design'
#  'engineering' 'fms' 'generative' 'industrial' 'machine' 'manufacturers'
#  'manufacturing' 'new' 'product' 'production' 'scot' 'supply']
#
#
# File: CMD Solutions Case Study _ AWS.txt
# Keywords: ['aws' 'certification' 'cloud' 'cmd' 'company' 'consultants' 'customer'
#  'customers' 'demand' 'employees' 'increase' 'learncmd' 'percent'
#  'program' 'revenue' 'services' 'skills' 'solutions' 'training' 'using']
#
#
# File: Using Amazon SageMaker to accelerate and deploy predictive editorial analytics solutions _ Smartocto Case Study _ AWS.txt
# Keywords: ['amazon' 'analytics' 'aws' 'company' 'content' 'customers' 'data'
#  'editorial' 'ml' 'models' 'months' 'new' 'sagemaker' 'says' 'smartify'
#  'smartocto' 'solution' 'team' 'time' 'using']
#
#
# File: Samsung Electronics Uses Amazon Chime SDK to Deliver a More Engaging Television Experience for Millions of Viewers _ Samsung Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'chat' 'chatting' 'chime' 'company' 'demand' 'electronics'
#  'engaging' 'experience' 'interactive' 'live' 'new' 'samsung' 'sdk'
#  'service' 'solution' 'television' 'using' 'viewers']
#
#
# File: Armitage Technologies case study.txt
# Keywords: ['access' 'application' 'armitage' 'aws' 'cameras' 'computer' 'data'
#  'edge' 'events' 'ip' 'lam' 'needed' 'organization' 'panorama' 'public'
#  'security' 'solution' 'technologies' 'video' 'vision']
#
#
# File: Ganit Transforms Fast Fashion Apparel Retail with Intelligent Demand Forecasting on AWS _ AWS Partner Network (APN) Blog.txt
# Keywords: ['amazon' 'aws' 'based' 'data' 'demand' 'figure' 'forecast' 'forecasting'
#  'ganit' 'inventory' 'like' 'management' 'model' 'partner' 'sales' 'skus'
#  'stock' 'time' 'used' 'using']
#
#
# File: Facilitating the Most Live Streamed Super Bowl and Olympics Using AWS Services _ NBCUniversal Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'bowl' 'cloudfront' 'concurrent' 'content' 'elemental'
#  'live' 'media' 'million' 'nbcuniversal' 'olympics' 'peacock' 'says'
#  'service' 'services' 'streaming' 'super' 'using' 'video']
#
#
# File: Illumina Case Study _ Genomics _ AWS.txt
# Keywords: ['amazon' 'analyses' 'aws' 'cloud' 'cost' 'customers' 'data' 'dragen' 'ec'
#  'genomics' 'human' 'illumina' 'instances' 'samples' 'says' 'sequencing'
#  'service' 'software' 'solutions' 'storage']
#
#
# File: Rackspace Automates Infrastructure Management across Cloud Providers Using AWS Systems Manager _ Rackspace Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'cloud' 'cloudwatch' 'complexity' 'customers'
#  'infrastructure' 'management' 'manager' 'multicloud' 'patching' 'prewitt'
#  'rackspace' 'says' 'services' 'solution' 'systems' 'technology' 'using'
#  'vm']
#
#
# File: Tangent Works Case Study.txt
# Keywords: ['amazon' 'aws' 'businesses' 'compute' 'customers' 'data' 'learning'
#  'machine' 'modeling' 'models' 'scale' 'service' 'services' 'siemens'
#  'tangent' 'technology' 'tim' 'use' 'using' 'works']
#
#
# File: Veolia Australia and New Zealand Case Study - Amazon Web Services (AWS).txt
# Keywords: ['amazon' 'applications' 'australia' 'aws' 'cloud' 'cmd' 'data' 'database'
#  'environment' 'infrastructure' 'migration' 'nandavaram' 'new' 'says'
#  'security' 'service' 'services' 'sql' 'using' 'veolia']
#
#
# File: Upskilling Over 2K Employees with AWS Training and Certification and Creating a Culture of Innovation _ Techcombank Case Study _ AWS.txt
# Keywords: ['applications' 'aws' 'bank' 'certification' 'change' 'cloud' 'culture'
#  'customer' 'customers' 'digital' 'employees' 'innovation' 'learning'
#  'products' 'says' 'services' 'skills' 'techcombank' 'training' 'vietnam']
#
#
# File: Creating an App for 12000 Game Show Viewers Using Amazon CloudFront with TUI _ TUI Case Study _ AWS.txt
# Keywords: ['amazon' 'app' 'application' 'audience' 'aws' 'build' 'cloudfront'
#  'company' 'cost' 'game' 'onpremises' 'says' 'service' 'solution' 'time'
#  'travel' 'tui' 'used' 'using' 'voting']
#
#
# File: FLYING WHALES Case Study.txt
# Keywords: ['airship' 'amazon' 'aws' 'cargo' 'cfd' 'cloud' 'company' 'compute' 'ec'
#  'engineers' 'environment' 'faster' 'flying' 'hpc' 'instances' 'martinat'
#  'says' 'support' 'using' 'whales']
#
#
# File: Reducing Log Data Storage Cost Using Amazon OpenSearch Service with CMS _ Case Study _ AWS.txt
# Keywords: ['agency' 'amazon' 'aws' 'cms' 'costs' 'data' 'healthcare' 'log'
#  'medicaid' 'medicare' 'opensearch' 'says' 'security' 'service' 'services'
#  'solution' 'spitz' 'storage' 'use' 'using']
#
#
# File: Fine-tune GPT-J using an Amazon SageMaker Hugging Face estimator and the model parallel library _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'data' 'distributed' 'face' 'gptj' 'gpu' 'hugging' 'learning'
#  'library' 'memory' 'model' 'models' 'parallel' 'parallelism' 'sagemaker'
#  'smp' 'tensor' 'training' 'use' 'using']
#
#
# File: SUPINFO Creates 5-Year Master of Engineering Degree Implementing AWS Education Programs _ Case Study _ AWS.txt
# Keywords: ['academy' 'aws' 'certifications' 'cloud' 'computing' 'curriculum'
#  'education' 'engineering' 'experience' 'future' 'handson'
#  'industryrecognized' 'learn' 'master' 'program' 'programs' 'services'
#  'skills' 'students' 'supinfo']
#
#
# File: NTT DOCOMO builds a new data analysis platform for 9000 workers with AWS attracting 13 times more users and invigorating data use _ NTT Docomo Case Study _ AWS.txt
# Keywords: ['analytics' 'aws' 'catalogs' 'cloud' 'cost' 'data' 'departments' 'docomo'
#  'environments' 'group' 'information' 'new' 'ntt' 'platform' 'services'
#  'systems' 'tools' 'use' 'user' 'users']
#
#
# File: Building a Scalable Interactive Learning Application for Kids Using AWS Services with Yellow Class _ Case Study _ AWS.txt
# Keywords: ['amazon' 'application' 'aws' 'class' 'company' 'compute' 'costs'
#  'elemental' 'jindal' 'learn' 'like' 'performance' 'reduced' 'service'
#  'services' 'users' 'using' 'video' 'videos' 'yellow']
#
#
# File: CalvertHealth-case-study.txt
# Keywords: ['aws' 'backup' 'calverthealth' 'calverthealths' 'data' 'disaster' 'ehr'
#  'hall' 'healthcare' 'hospital' 'information' 'organizations' 'recovery'
#  'resilience' 'rto' 'says' 'services' 'staff' 'time' 'using']
#
#
# File: Democratize computer vision defect detection for manufacturing quality using no-code machine learning with Amazon SageMaker Canvas _ AWS Machine Learning Blog.txt
# Keywords: ['accuracy' 'amazon' 'build' 'canvas' 'choose' 'dataset' 'defect'
#  'defects' 'image' 'images' 'import' 'labels' 'ml' 'model' 'prediction'
#  'predictions' 'quality' 'sagemaker' 'training' 'use']
#
#
# File: Revive lost revenue from bad ecommerce search using Natural Language Processing _ AWS for Industries.txt
# Keywords: ['amazon' 'aws' 'comprehend' 'ecommerce' 'engine' 'example' 'experience'
#  'language' 'looking' 'opensearch' 'product' 'results' 'retailers'
#  'revenue' 'search' 'searches' 'service' 'shoppers' 'user' 'users']
#
#
# File: Optimizing Storage Cost and Performance Using Amazon EBS _ Devo Case Study _ AWS.txt
# Keywords: ['amazon' 'analytics' 'aws' 'capacity' 'cloud' 'company' 'compute' 'cost'
#  'customers' 'data' 'devo' 'ebs' 'organizations' 'performance' 'security'
#  'service' 'solutions' 'storage' 'using' 'volumes']
#
#
# File: Concert.ua Manages 1000 Traffic Spikes Using AWS Serverless _ AWS EC2.txt
# Keywords: ['amazon' 'aurora' 'aws' 'compute' 'concertua' 'customers' 'fargate'
#  'infrastructure' 'lambda' 'lysenko' 'says' 'serverless' 'servers'
#  'service' 'services' 'spikes' 'ticketing' 'time' 'traffic' 'using']
#
#
# File: GoDaddy Case Study _ AWS.txt
# Keywords: ['accounts' 'amazon' 'application' 'aws' 'central' 'cirrusscan' 'findings'
#  'godaddy' 'godaddys' 'hub' 'management' 'managing' 'says' 'scans'
#  'security' 'serverless' 'service' 'tools' 'use' 'using']
#
#
# File: DBS Bank Uses Amazon ElastiCache for Redis to Run Its Pricing Models at Real-Time Speed _ DBS Bank Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'bank' 'cloud' 'customers' 'data' 'dbs' 'ec' 'elasticache'
#  'instances' 'liu' 'performance' 'pricing' 'qpe' 'redis' 'says' 'scale'
#  'services' 'trading' 'using']
#
#
# File: Processing Data 10x Faster Using Amazon Redshift Serverless with BlocPower _ BlocPower Case Study _ AWS.txt
# ...
#  'says' 'services' 'set' 'spacelift' 'tasks' 'time' 'using' 'wyszynski']
#
#
# File: PayEye Launches POC for Biometric Payments in 5 Months Using AWS _ Amazon EKS.txt
# Keywords: ['amazon' 'applications' 'aws' 'biometric' 'company' 'concept' 'customer'
#  'data' 'months' 'payeye' 'payment' 'proof' 'says' 'security' 'service'
#  'services' 'technology' 'uses' 'using' 'yczba']
#
#
# File: SKODA Uses AWS to Predict and Prevent Production Line Breakdowns.txt
# Keywords: ['amazon' 'approach' 'assembly' 'aws' 'compute' 'data' 'ddek' 'downtime'
#  'eye' 'koda' 'line' 'magic' 'maintenance' 'potential' 'production'
#  'service' 'services' 'solution' 'uses' 'using']
#
#
# File: The positive impact Generative AI could have for Retail _ AWS for Industries.txt
# Keywords: ['ai' 'aiml' 'amazon' 'available' 'aws' 'best' 'code' 'comments' 'david'
#  'fms' 'genai' 'generative' 'images' 'language' 'model' 'product' 'retail'
#  'retailers' 'rules' 'use']
#
#
# File: Mobileye Improves Deep Learning Training Performance and Reduces Costs Using Amazon EC2 DL1 Instances _ Mobileye Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'cloud' 'company' 'compute' 'dl' 'ec' 'eks' 'elastic'
#  'instances' 'kubernetes' 'mobileye' 'models' 'performance' 'price'
#  'shitrit' 'training' 'use' 'using' 'workloads']
#
#
# File: Resilience Builds a Global Data Mesh for Lab Connectivity on AWS _ Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'cloud' 'company' 'data' 'development' 'insights'
#  'instruments' 'lab' 'manufacturing' 'network' 'research' 'resilience'
#  'says' 'scientists' 'service' 'services' 'sites' 'transfer' 'using']
#
#
# File: SmartSearch-case-study.txt
# Keywords: ['amazon' 'application' 'aws' 'clients' 'cloud' 'company' 'compute' 'data'
#  'environment' 'migration' 'morris' 'network' 'performance' 'rednight'
#  'says' 'servers' 'service' 'smartsearch' 'software' 'using']
#
#
# File: DCI Saves 27 on Cloud Costs Gains Support for Long-Term Growth Using AWS _ Amazon EC2.txt
# Keywords: ['amazon' 'aws' 'cloud' 'cloudwatch' 'company' 'compute' 'costs'
#  'customers' 'data' 'dci' 'help' 'intelligence' 'market' 'months'
#  'provider' 'service' 'services' 'support' 'tools' 'using']
#
#
# File: Global Unichip Corporation Case Study.txt
# Keywords: ['amazon' 'asic' 'asics' 'aws' 'cloud' 'customers' 'data' 'development'
#  'dies' 'ec' 'elkanovich' 'guc' 'instances' 'proteantecs' 'quality'
#  'reliability' 'semiconductor' 'spot' 'technology' 'using']
#
#
# File: Respond.io Scales Its Messaging Platform and Connects 10000 Companies with Customers on AWS _ Respond.io Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'business' 'chat' 'companies' 'customer' 'customers'
#  'handle' 'marketing' 'messages' 'messaging' 'opensearch' 'platform'
#  'respondio' 'sales' 'scale' 'search' 'serverless' 'service' 'support']
#
#
# File: AWS Case Study - StreamAMG.txt
# Keywords: ['amazon' 'application' 'aws' 'company' 'cost' 'data' 'deliver' 'live'
#  'matches' 'needed' 'new' 'percent' 'scale' 'season' 'service' 'sports'
#  'streamamg' 'streamamgs' 'streaming' 'usage']
#
#
# File: ResMed Case Study _ AWS AppSync _ AWS.txt
# Keywords: ['application' 'appsync' 'aws' 'company' 'continuous' 'data' 'fully'
#  'hickey' 'managed' 'myair' 'new' 'resmed' 'says' 'serverless' 'service'
#  'solutions' 'time' 'user' 'users' 'using']
#
#
# File: Amazon OpenSearch Services vector database capabilities explained _ AWS Big Data Blog.txt
# Keywords: ['algorithms' 'amazon' 'customers' 'database' 'knn' 'like' 'low' 'memory'
#  'number' 'opensearch' 'product' 'query' 'score' 'search' 'semantic'
#  'service' 'similarity' 'use' 'vector' 'vectors']
#
#
# File: Fujita Health University Case Study _ Amazon Web Services.txt
# Keywords: ['amazon' 'applications' 'aws' 'business' 'care' 'data' 'emr' 'fhir'
#  'fujita' 'health' 'healthcare' 'kobayashi' 'largest' 'medical' 'patient'
#  'patients' 'phr' 'records' 'systems' 'university']
#
#
# File: Power recommendation and search using an IMDb knowledge graph  Part 1 _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'aws' 'choose' 'complete' 'data' 'enter' 'exchange' 'following'
#  'graph' 'gremlin' 'imdb' 'load' 'ml' 'movie' 'movies' 'neptune' 'query'
#  'rating' 'use' 'using']
#
#
# File: Build a powerful question answering bot with Amazon SageMaker Amazon OpenSearch Service Streamlit and LangChain _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'api' 'application' 'aws' 'data' 'documents' 'embeddings'
#  'following' 'function' 'lambda' 'notebook' 'opensearch' 'question' 'run'
#  'sagemaker' 'service' 'streamlit' 'url' 'use' 'user']
#
#
# File: AppsFlyer Amazon EKS Case Study _ Advertising _ AWS.txt
# Keywords: ['amazon' 'appsflyer' 'aws' 'cloud' 'company' 'compute' 'customers' 'data'
#  'ec' 'eks' 'graviton' 'improved' 'infrastructure' 'kubernetes'
#  'performance' 'reduced' 'running' 'service' 'using' 'workloads']
#
#
# File: Highlight text as its being spoken using Amazon Polly _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'api' 'audio' 'aws' 'browser' 'code' 'file' 'files' 'following'
#  'function' 'javascript' 'lambda' 'marks' 'polly' 'solution' 'speech'
#  'spoken' 'text' 'using' 'word']
#
#
# File: Train a Large Language Model on a single Amazon SageMaker GPU with Hugging Face and LoRA _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'aws' 'dataset' 'face' 'finetuning' 'gpu' 'hugging' 'import'
#  'instance' 'job' 'lora' 'model' 'models' 'number' 'sagemaker' 'sample'
#  'training' 'use' 'using' 'weights']
#
#
# File: Creating Air Taxi Simulations Using Amazon EC2 with Wisk Aero _ Wisk Aero Case Study _ AWS.txt
# Keywords: ['aero' 'aircraft' 'amazon' 'aws' 'build' 'cfd' 'clusters' 'company'
#  'compute' 'converge' 'ec' 'govcloud' 'hpc' 'onpremises' 'performance'
#  'simulations' 'storage' 'team' 'using' 'wisk']
#
#
# File: Isha Foundation Delivers on its Mission for Millions by Transforming Content Delivery on AWS _ Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'cloudfront' 'content' 'delivery' 'elastic' 'events'
#  'experience' 'foundation' 'isha' 'kubernetes' 'mathivanan' 'online'
#  'resources' 'says' 'service' 'spiritual' 'support' 'users' 'websites']
#
#
# File: DTN Case Study _ HPC _ AWS.txt
# Keywords: ['amazon' 'aws' 'chenevert' 'company' 'customers' 'data' 'dtn' 'ec'
#  'forecast' 'global' 'hpc' 'instances' 'intelligence' 'organizations'
#  'performance' 'says' 'service' 'services' 'using' 'weather']
#
#
# File: Effectively solve distributed training convergence issues with Amazon SageMaker Hyperband Automatic Model Tuning _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'amt' 'convergence' 'data' 'distributed' 'hyperband'
#  'hyperparameters' 'instances' 'job' 'jobs' 'metric' 'model' 'number'
#  'sagemaker' 'set' 'time' 'training' 'tuning' 'use' 'using']
#
#
# File: Increasing Sales Opportunities by 83 Working with AWS Training and Certification with Fortinet _ Case Study _ AWS.txt
# Keywords: ['aws' 'business' 'certification' 'cloud' 'cosell' 'customer' 'customers'
#  'engagements' 'fortinet' 'global' 'learn' 'opportunities' 'program'
#  'programs' 'sales' 'services' 'software' 'solutions' 'training' 'using']
#
#
# File: The Next Frontier_ Generative AI for Financial Services _ AWS for Industries.txt
# Keywords: ['ai' 'amazon' 'applications' 'aws' 'build' 'customer' 'customers' 'data'
#  'financial' 'fms' 'generative' 'including' 'investment' 'like' 'llms'
#  'ml' 'models' 'new' 'services' 'use']
#
#
# File: Tally Solutions _ Amazon Web Services.txt
# Keywords: ['access' 'amazon' 'application' 'aws' 'business' 'businesses' 'cloud'
#  'customers' 'dcv' 'elcom' 'joyce' 'nice' 'remote' 'software' 'solution'
#  'solutions' 'tally' 'tallyprime' 'user' 'users']
#
#
# File: Coventry University Group Empowers Next Generation of IT Professionals Using AWS Educate and AWS Academy _ Case Study _ AWS.txt
# Keywords: ['aws' 'bachelor' 'careers' 'cloud' 'computing' 'coventry' 'cu' 'degree'
#  'education' 'experience' 'group' 'industry' 'learn' 'needs' 'programs'
#  'science' 'services' 'skills' 'students' 'university']
#
#
# File: AWS Case Study - Ineos Team UK.txt
# Keywords: ['amazon' 'americas' 'aws' 'boat' 'cloud' 'cup' 'design' 'ec' 'hpc'
#  'ineos' 'instances' 'performance' 'race' 'simulations' 'spot' 'team'
#  'thousands' 'time' 'uk' 'using']
#
#
# File: iptiQ Case Study.txt
# Keywords: ['amazon' 'aws' 'cloud' 'common' 'customer' 'customers' 'digital' 'easier'
#  'insurance' 'iptiq' 'learn' 'partners' 'pozzoli' 'products' 'says'
#  'service' 'services' 'solutions' 'swiss' 'using']
#
#
# File: Mediality Leverages Automation to Deliver Racing Data Faster on AWS _ Case Study _ AWS.txt
# Keywords: ['aap' 'amplify' 'api' 'aws' 'business' 'cevo' 'cloud' 'code' 'company'
#  'customers' 'data' 'database' 'development' 'faster' 'lambda' 'learn'
#  'mediality' 'racing' 'services' 'workflows']
#
#
# File: Helping Patients Access Personalized Healthcare from Anywhere Using Amazon Chime SDK with Salesforce _ Salesforce Case Study _ AWS.txt
# Keywords: ['amazon' 'applications' 'aws' 'care' 'chime' 'customers' 'event' 'health'
#  'healthcare' 'patients' 'provide' 'salesforce' 'scalable' 'sdk' 'service'
#  'services' 'solution' 'using' 'video' 'virtual']
#
#
# File: TC Energy Builds an Operations Data Platform for 60000 Miles of Pipeline Using AWS Data Analytics _ TC Energy Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'company' 'data' 'energy' 'energys' 'glue' 'lake'
#  'operations' 'pariveda' 'pipeline' 'says' 'serverless' 'service'
#  'services' 'sources' 'tc' 'team' 'use' 'using']
#
#
# File: Implement unified text and image search with a CLIP model using Amazon SageMaker and Amazon OpenSearch Service _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'clip' 'data' 'embeddings' 'image' 'images' 'import' 'index'
#  'inference' 'item' 'knn' 'model' 'opensearch' 'query' 'sagemaker'
#  'search' 'service' 'text' 'use' 'using']
#
#
# File: 23andMe Case Study _ Life Sciences _ AWS.txt
# Keywords: ['amazon' 'andme' 'aws' 'cloud' 'company' 'compute' 'costs' 'data' 'ec'
#  'leon' 'map' 'migration' 'performance' 'program' 'running' 'says'
#  'scalability' 'services' 'storage' 'using']
#
#
# File: Saving time with personalized videos using AWS machine learning _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'aws' 'clipr' 'content' 'customers' 'data' 'meeting' 'ml'
#  'moments' 'reinvent' 'sagemaker' 'search' 'services' 'sessions' 'time'
#  'topics' 'using' 'video' 'videos' 'view']
#
#
# File: Lendingkart _ Amazon Web Services.txt
# Keywords: ['amazon' 'aws' 'business' 'cloud' 'credit' 'customers' 'development'
#  'elastic' 'factory' 'gthr' 'lendingkart' 'loans' 'msmes' 'platform'
#  'product' 'saas' 'service' 'services' 'singh' 'underwriting']
#
#
# File: Staffordshire University Uses AWS Academy to Help Students Meet Business Demand for Cloud Skills _ Case Study _ AWS.txt
# Keywords: ['academy' 'aws' 'cloud' 'computing' 'courses' 'curriculum' 'digital' 'dr'
#  'education' 'kingdom' 'learn' 'learner' 'programs' 'services' 'skills'
#  'staffordshire' 'students' 'united' 'university' 'using']
#
#
# File: Idealo Case Study.txt
# Keywords: ['aws' 'build' 'clickthrough' 'company' 'customers' 'data' 'idealo'
#  'learning' 'machine' 'ml' 'model' 'models' 'products' 'rates'
#  'recommendations' 'says' 'service' 'team' 'use' 'using']
#
#
# File: Better Mortgage using Amazon Elastic Kubernetes _ Better Mortgage Video _ AWS.txt
# Keywords: ['amazon' 'aws' 'better' 'builds' 'concept' 'contact' 'day' 'eks'
#  'elastic' 'equity' 'innovative' 'journey' 'kubernetes' 'learn' 'mortgage'
#  'payment' 'service' 'services' 'solutions' 'unlocker']
#
#
# File: Novo Nordisk Uses ML for Computer Vision to Optimize Pharmaceutical Manufacturing on AWS _ Novo Nordisk Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'cloud' 'company' 'deploy' 'edge' 'ml' 'model' 'models'
#  'nordisk' 'novo' 'pipeline' 'process' 'sagemaker' 'service' 'services'
#  'team' 'use' 'uses' 'using']
#
#
# File: Host ML models on Amazon SageMaker using Triton_ ONNX Models _ AWS Machine Learning Blog.txt
# Keywords: ['allocation' 'amazon' 'arena' 'batch' 'configuration' 'create' 'default'
#  'endpoint' 'following' 'inference' 'memory' 'model' 'models' 'onnx'
#  'performance' 'sagemaker' 'set' 'size' 'triton' 'use']
#
#
# File: Evolving ADPs Single Global Experience in MyADP and ADP Mobile Using AWS Lambda _ Case Study _ AWS.txt
# Keywords: ['adp' 'amazon' 'application' 'architecture' 'aws' 'company' 'data'
#  'experience' 'global' 'latency' 'mobile' 'ramachandran' 'says'
#  'serverless' 'service' 'services' 'team' 'used' 'using' 'ux']
#
#
# File: Infor Case Study.txt
# Keywords: ['amazon' 'aws' 'better' 'carlin' 'certification' 'cloud' 'course'
#  'courses' 'customer' 'customers' 'employees' 'infor' 'learn' 'needs'
#  'personnel' 'says' 'service' 'services' 'solutions' 'training']
#
#
# File: How Marubeni is optimizing market decisions using AWS machine learning and analytics _ AWS Machine Learning Blog.txt
# Keywords: ['amazon' 'aws' 'bid' 'bids' 'business' 'data' 'energy' 'functions'
#  'machine' 'market' 'marubeni' 'ml' 'model' 'models' 'new' 'optimization'
#  'power' 'sagemaker' 'solution' 'using']
#
#
# File: Improving Mergers and Acquisitions Using AWS Organizations with Warner Bros. Discovery _ Warner Bros. Discovery Case Study _ AWS.txt
# Keywords: ['account' 'accounts' 'aws' 'bros' 'centralized' 'cloud' 'company'
#  'deployment' 'discovery' 'governance' 'new' 'organizations' 'process'
#  'says' 'security' 'services' 'teams' 'time' 'using' 'wbd']
#
#
# File: Thomson Reuters Uses Amazon DMA to Accelerate Database Modernization _ Thomson Reuters Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'company' 'data' 'database' 'databases' 'dma' 'dms'
#  'experts' 'key' 'matzek' 'migrate' 'migration' 'reuters' 'says' 'sct'
#  'service' 'services' 'thomson' 'using']
#
#
# File: WaFd Bank Transforms Contact Centers Using Conversational AI on AWS _ Case Study _ AWS.txt
# Keywords: ['agent' 'agents' 'ai' 'amazon' 'aws' 'bank' 'banking' 'center' 'contact'
#  'conversational' 'customer' 'customers' 'experience' 'lex' 'new'
#  'solution' 'talkdesk' 'using' 'voice' 'wafd']
#
#
# File: Arm Limited Case Study.txt
# Keywords: ['amazon' 'arm' 'aws' 'batch' 'cloud' 'company' 'compute' 'ec' 'eda'
#  'instance' 'instances' 'jobs' 'run' 'says' 'solution' 'spot' 'types'
#  'using' 'workloads' 'yun']
#
#
# File: Upstox Saves 1 Million Annually Using Amazon S3 Storage Lens _ Upstox Case Study _ AWS.txt
# Keywords: ['amazon' 'annually' 'athena' 'aws' 'business' 'cost' 'costs' 'data'
#  'lake' 'lens' 'million' 'optimize' 'retrieval' 'service' 'services'
#  'storage' 'stored' 'upstox' 'usage' 'using']
#
#
# File: Zoox Case Study _ Automotive _ AWS.txt
# Keywords: ['amazon' 'autonomous' 'aws' 'cloud' 'computing' 'data' 'development' 'ec'
#  'herrmann' 'onpremises' 'petabytes' 'run' 'says' 'service' 'use' 'using'
#  'vehicle' 'vehicles' 'workloads' 'zoox']
#
#
# File: Delivering Engaging Games at Scale Using AWS with Whatwapp _ Case Study _ AWS.txt
# Keywords: ['amazon' 'aws' 'backend' 'company' 'data' 'eks' 'features' 'game' 'games'
#  'gaming' 'infrastructure' 'kubernetes' 'nakama' 'new' 'players' 'says'
#  'service' 'time' 'using' 'whatwapp']
#
#
# File: Technology that delivers_ iFood and Appoena gain agility with AWS Marketplace _ iFood Case Study _ AWS.txt
# Keywords: ['appoena' 'aws' 'continues' 'customer' 'delivery' 'food' 'ifood' 'lemos'
#  'manage' 'marketplace' 'observability' 'process' 'procurement' 'saas'
#  'says' 'services' 'software' 'solution' 'teams' 'using']
#
#
# File: Stanford Multimodal Data Case Study _ Life Sciences _ AWS.txt
# Keywords: ['access' 'amazon' 'aws' 'data' 'ddrcc' 'health' 'large' 'medical'
#  'medicine' 'myphd' 'precision' 'research' 'researchers' 'scale' 'sdo'
#  'security' 'service' 'solutions' 'stanford' 'using']
#
#
# File: Ultrasound Business Area Improves Customer Experience Using AWS Systems Manager _ Siemens Healthineers Case Study _ AWS.txt
# Keywords: ['amazon' 'area' 'aws' 'business' 'cloud' 'devices' 'healthcare'
#  'healthineers' 'manager' 'new' 'remote' 'service' 'services' 'siemens'
#  'solution' 'systems' 'team' 'time' 'ultrasound' 'using']
#
#
# File: Ultra Commerce Case Study.txt
# Keywords: ['amazon' 'aurora' 'aws' 'business' 'businesses' 'commerce' 'container'
#  'customers' 'data' 'ecommerce' 'elastic' 'fully' 'innovation' 'managed'
#  'platform' 'serverless' 'service' 'services' 'solution' 'ultra']

# %%
import matplotlib.pyplot as plt
from nltk.tree import Tree

# Convert named entities to tree structure
tree = Tree.fromstring(str(named_entities))

# Visualize the tree
tree.draw()
